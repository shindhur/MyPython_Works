# %%
import pandas as pd
import seaborn as sb
import numpy as np

import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format

def lowercase(args):
  if isinstance(args, str):
      return args.lower()

print("Performing Data Cleanup On Companies Data")
df_companies = pd.read_csv("../../../../../Assignments/InvestmentAnalysis/companies.txt", encoding='unicode_escape', sep="\t");
df_companies = df_companies.drop_duplicates(subset='permalink')
df_companies['permalink'] = df_companies['permalink'].str.lower()

round(100*(df_companies.isnull().sum()/len(df_companies.index)), 2)
df_companies['country_code'].isnull().sum()
df_companies = df_companies[~pd.isnull(df_companies['country_code'])]
df_companies.isnull().sum()

df_companies.loc[pd.isnull(df_companies['category_list']), ['category_list']] = 'Others'
df_companies.isnull().sum()

print("Performing Data Cleanup On Rounds Data")
df_rounds = pd.read_csv("../../../../../Assignments/InvestmentAnalysis/rounds2.csv", encoding='unicode_escape');
df_rounds['company_permalink'] = df_rounds['company_permalink'].str.lower()
df_rounds.loc[pd.isnull(df_rounds['raised_amount_usd']), ['raised_amount_usd']] = df_rounds['raised_amount_usd'].mean()

#Table 1.1 How many unique companies are present in rounds2?
df_rounds_unique_companies = df_rounds['company_permalink'].unique();
print(df_rounds_unique_companies.size)

#Table 1.1 How many unique companies are present in companies?
df_companies_unique_companies = df_companies['permalink'].unique();
print(df_companies_unique_companies.size)

#Table 1.1 Any companies in the rounds2 file which are not present in companies??
unique_companies_in_rounds = pd.Series(df_rounds['company_permalink'].isin(df_companies['permalink']))

#Table 1.1 How many observations are present in master_frame?
master_frame = pd.merge(df_companies, df_rounds, left_on="permalink", right_on="company_permalink", how="outer")
print(master_frame.shape)
print("--------------------------------- End of Table 1 -------------------------------------")


print("Performing Data Manipulation by replacing Null Raised Amount USD values with Mean and Cleaning up Null funding_round_type rows")
master_frame.loc[pd.isnull(master_frame['raised_amount_usd']), ['raised_amount_usd']] = master_frame['raised_amount_usd'].mean()
master_frame = master_frame[~pd.isnull(master_frame['funding_round_type'])]
master_frame.isnull().sum()

#Table 2.1 Most representative value of the investment amount for each of the four funding types (venture, angel, seed, and private equity)
master_frame_grouped_df = master_frame.groupby(['funding_round_type'])
master_frame_repvalue_df = pd.DataFrame(master_frame_grouped_df['raised_amount_usd'].mean().sort_values(ascending=False)).reset_index()

#Table 2.2 Based on the most representative investment amount calculated above, which investment type do you think is the most suitable for Spark Funds ?
print("After Getting Mean --> Venture is Best")
print("--------------------------------- End of Table 2 -------------------------------------")


print(master_frame_repvalue_df)        # Needed for Plot 1
print(master_frame_repvalue_df.info())

venture_df = pd.DataFrame(master_frame.loc[master_frame['funding_round_type'] == 'venture'])
print(venture_df)

selected_venture_grouped_df = venture_df.groupby(['country_code'])
#Spark Funds wants to see the top nine countries which have received the highest total funding
top9 = pd.DataFrame(selected_venture_grouped_df['raised_amount_usd'].sum().sort_values(ascending=False)).reset_index()

#For the chosen investment type, make a data frame named top9 with the top nine countries
print(top9.head(9))


print(venture_df['category_list'])

#Extract the primary sector of each category list from the category_list column
venture_df['primary_sector'] = venture_df['category_list'].apply(lambda x : str(x).split('|')[0])
venture_df['primary_sector'] = venture_df['primary_sector'].apply(lambda x: lowercase(x))


mapping_df = pd.read_csv("../../../../../Assignments/InvestmentAnalysis/mapping.csv", encoding='unicode_escape');
mapping_df['category_list'] = mapping_df['category_list'].apply(lambda x: lowercase(x))
melted_mapping_df = pd.melt(mapping_df, id_vars=['category_list'], value_vars=['Automotive & Sports',	'Blanks',
                                                'Cleantech / Semiconductors',
                                                'Entertainment', 'Health',
                                                'Manufacturing',	'News, Search and Messaging',
                                                'Others',	'Social, Finance, Analytics, Advertising'])

melted_mapping_df = melted_mapping_df[melted_mapping_df.value != 0]
melted_mapping_df = melted_mapping_df.rename(columns = {'variable':'main_sector'})

# Map each primary sector to one of the eight main sectors
categories_list_frame = pd.merge(venture_df, melted_mapping_df, left_on="primary_sector", right_on="category_list", how="inner")

#Create three separate data frames D1, D2 and D3 for each of the three countries containing the observations of funding type FT falling within the 5-15 million USD range
usa_dataframe = pd.DataFrame(categories_list_frame.loc[categories_list_frame['country_code'] == 'USA'])
gbr_dataframe = pd.DataFrame(categories_list_frame.loc[categories_list_frame['country_code'] == 'GBR'])
ind_dataframe = pd.DataFrame(categories_list_frame.loc[categories_list_frame['country_code'] == 'IND'])

usa_grouped_df = pd.DataFrame(usa_dataframe.groupby(['country_code','main_sector']).raised_amount_usd.agg(['count','sum']))
print(usa_grouped_df)
print(usa_grouped_df['count'].sum())
print(usa_grouped_df['sum'].sum())

gbr_grouped_df = pd.DataFrame(gbr_dataframe.groupby(['country_code','main_sector']).raised_amount_usd.agg(['count','sum']))
print(gbr_grouped_df)
print(gbr_grouped_df['count'].sum())
print(gbr_grouped_df['sum'].sum())

ind_grouped_df = pd.DataFrame(ind_dataframe.groupby(['country_code','main_sector']).raised_amount_usd.agg(['count','sum']))
print(ind_grouped_df)
print(ind_grouped_df['count'].sum())
print(ind_grouped_df['sum'].sum())

# For the top sector count-wise (point 3), which company received the highest investment
top_sector_countwise_company_usa = pd.DataFrame(usa_dataframe.loc[usa_dataframe['main_sector'] == 'Others'])
top_sector_countwise_company_usa = top_sector_countwise_company_usa[pd.notnull(top_sector_countwise_company_usa['raised_amount_usd'])]
top_sector_countwise_company_usa = top_sector_countwise_company_usa.sort_values('raised_amount_usd', ascending=False)
print(top_sector_countwise_company_usa)

top_sector_countwise_company_gbr = pd.DataFrame(gbr_dataframe.loc[gbr_dataframe['main_sector'] == 'Others'])
top_sector_countwise_company_gbr = top_sector_countwise_company_gbr[pd.notnull(top_sector_countwise_company_gbr['raised_amount_usd'])]
top_sector_countwise_company_gbr = top_sector_countwise_company_gbr.sort_values('raised_amount_usd', ascending=False)
print(top_sector_countwise_company_gbr)

top_sector_countwise_company_ind = pd.DataFrame(ind_dataframe.loc[ind_dataframe['main_sector'] == 'Others'])
top_sector_countwise_company_ind = top_sector_countwise_company_ind[pd.notnull(top_sector_countwise_company_ind['raised_amount_usd'])]
top_sector_countwise_company_ind = top_sector_countwise_company_ind.sort_values('raised_amount_usd', ascending=False)
print(top_sector_countwise_company_ind)

#For the second-best sector count-wise (point 4), which company received the highest investment?
print(pd.DataFrame(usa_dataframe.loc[usa_dataframe['main_sector'] == 'Cleantech / Semiconductors']).sort_values(by="raised_amount_usd",ascending=False))
print(pd.DataFrame(gbr_dataframe.loc[gbr_dataframe['main_sector'] == 'Cleantech / Semiconductors']).sort_values(by="raised_amount_usd",ascending=False))
print(pd.DataFrame(ind_dataframe.loc[ind_dataframe['main_sector'] == 'News, Search and Messaging']).sort_values(by="raised_amount_usd",ascending=False))

#usa_grouped_plot = pd.DataFrame(usa_dataframe.groupby(['country_code','main_sector']).raised_amount_usd.agg(['count'])).sort_values('count', ascending=False)
#print(usa_grouped_plot)

#gbr_grouped_plot = pd.DataFrame(gbr_dataframe.groupby(['country_code','main_sector']).raised_amount_usd.agg(['count'])).sort_values('count', ascending=False)
#print(gbr_grouped_plot)

#ind_grouped_plot = pd.DataFrame(ind_dataframe.groupby(['country_code','main_sector']).raised_amount_usd.agg(['count'])).sort_values('count', ascending=False)
#print(ind_grouped_plot)

#------------------------------------ 1st Plot ---------------------------
master_frame_repvalue_df['percentage'] = master_frame_repvalue_df['raised_amount_usd']/master_frame_repvalue_df['raised_amount_usd'].sum()*100
master_frame_repvalue_df = master_frame_repvalue_df.set_index(['funding_round_type'])
master_frame_repvalue_df = master_frame_repvalue_df.loc[master_frame_repvalue_df.index.isin(['private_equity','seed','venture'])]

plt.figure(figsize=(12, 12))
plt.subplot(1, 2, 1)
sb.barplot(x='percentage', y='funding_round_type', data=master_frame_repvalue_df.reset_index())
plt.title("Percentage Investment by Fund Type")

plt.subplot(1, 2, 2)
sb.barplot(x='raised_amount_usd',y='funding_round_type', data=master_frame_repvalue_df.reset_index(), estimator=np.mean)
plt.title("Average Investment by Fund Type")
plt.show()

#------------------------------------- 2nd Plot -------------------------------------
plt.figure(figsize=(10, 10))
sb.barplot(x='raised_amount_usd', y='country_code', data=top9.head(9))
plt.xlabel("Total Amount of Investment")
plt.ylabel("Top 9 Countries")
plt.show()

#-----------------------------------3rd Plot ------------------------------------------------------
usa_top3Sector = usa_dataframe.query('main_sector == ["Others", "Cleantech / Semiconductors","Social, Finance, Analytics, Advertising"]')
sb.catplot(y="main_sector", hue="country_code",data=usa_top3Sector,col="country_code",col_wrap=4 ,kind="count",height=2,aspect=2)

gbr_top3Sector = gbr_dataframe.query('main_sector == ["Others", "Cleantech / Semiconductors","Social, Finance, Analytics, Advertising"]')
sb.catplot(y="main_sector", hue="country_code",data=gbr_top3Sector,col="country_code",col_wrap=4 , kind="count",height=2,aspect=2)

ind_top3Sector = ind_dataframe.query('main_sector == ["Others", "News, Search and Messaging","Social, Finance, Analytics, Advertising"]')
sb.catplot(y="main_sector", hue="country_code",data=ind_top3Sector,col="country_code",col_wrap=4 , kind="count",height=2,aspect=2)

plt.show()
# Out:
# Performing Data Cleanup On Companies Data
# Performing Data Cleanup On Rounds Data
# 66370
# 59410
# (114949, 16)
# --------------------------------- End of Table 1 -------------------------------------
# Performing Data Manipulation by replacing Null Raised Amount USD values with Mean and Cleaning up Null funding_round_type rows
# After Getting Mean --> Venture is Best
# --------------------------------- End of Table 2 -------------------------------------
#        funding_round_type  raised_amount_usd
# 0           post_ipo_debt     168,704,571.82
# 1         post_ipo_equity      81,057,797.56
# 2          private_equity      63,704,338.51
# 3        secondary_market      32,286,688.52
# 4          debt_financing      16,839,124.59
# 5             undisclosed      13,274,760.37
# 6                 venture      11,623,492.82
# 7     equity_crowdfunding       6,698,567.41
# 8   non_equity_assistance       6,598,892.17
# 9                   grant       4,512,211.92
# 10       convertible_note       3,280,719.44
# 11                   seed       2,920,791.08
# 12                  angel       2,875,945.50
# 13   product_crowdfunding       1,893,691.36
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
# funding_round_type    14 non-null object
# raised_amount_usd     14 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 304.0+ bytes
# None
#                                   permalink                    name  \
# 0                       /organization/-fame                   #fame
# 1                    /organization/-qounter                :Qounter
# 3                     /organization/0-6-com                 0-6.com
# 4            /organization/004-technologies        004 Technologies
# 7       /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 9                      /organization/0xdata                  H2O.ai
# 10                     /organization/0xdata                  H2O.ai
# 11                     /organization/0xdata                  H2O.ai
# 21               /organization/1-mainstream            1 Mainstream
# 27            /organization/10-minutes-with         10 Minutes With
# 31                  /organization/1000lookz               1000Lookz
# 32               /organization/1000memories            1000memories
# 36            /organization/1000museums-com         1000museums.com
# 37            /organization/1000museums-com         1000museums.com
# 39            /organization/1000museums-com         1000museums.com
# 40            /organization/1000museums-com         1000museums.com
# 42            /organization/1000museums-com         1000museums.com
# 44                 /organization/1001-menus                 ZenChef
# 45                 /organization/1001-menus                 ZenChef
# 47                 /organization/1001-menus                 ZenChef
# 48         /organization/1001pharmacies-com      1001pharmacies.com
# 50                    /organization/1006-tv                 1006.tv
# 51                    /organization/1006-tv                 1006.tv
# 52                   /organization/100du-tv                100du.tv
# 53                   /organization/100du-tv                100du.tv
# 54                   /organization/100e-com                100e.com
# 55                   /organization/100e-com                100e.com
# 57                  /organization/100health                   Redox
# 59                    /organization/100plus                 100Plus
# 60                   /organization/1010data                1010data
# ...                                     ...                     ...
# 114856                                  NaN                     NaN
# 114858                                  NaN                     NaN
# 114865                                  NaN                     NaN
# 114866                                  NaN                     NaN
# 114868                                  NaN                     NaN
# 114869                                  NaN                     NaN
# 114876                                  NaN                     NaN
# 114886                                  NaN                     NaN
# 114887                                  NaN                     NaN
# 114891                                  NaN                     NaN
# 114892                                  NaN                     NaN
# 114899                                  NaN                     NaN
# 114900                                  NaN                     NaN
# 114901                                  NaN                     NaN
# 114902                                  NaN                     NaN
# 114910                                  NaN                     NaN
# 114911                                  NaN                     NaN
# 114912                                  NaN                     NaN
# 114917                                  NaN                     NaN
# 114918                                  NaN                     NaN
# 114919                                  NaN                     NaN
# 114924                                  NaN                     NaN
# 114925                                  NaN                     NaN
# 114926                                  NaN                     NaN
# 114929                                  NaN                     NaN
# 114936                                  NaN                     NaN
# 114939                                  NaN                     NaN
# 114942                                  NaN                     NaN
# 114946                                  NaN                     NaN
# 114947                                  NaN                     NaN
#
#                              homepage_url  \
# 0                      http://livfame.com
# 1                  http://www.qounter.com
# 3                      http://www.0-6.com
# 4       http://004gmbh.de/en/004-interact
# 7                    http://ondinebio.com
# 9                          http://h2o.ai/
# 10                         http://h2o.ai/
# 11                         http://h2o.ai/
# 21             http://www.1mainstream.com
# 27               http://10minuteswith.com
# 31                   http://1000lookz.com
# 32                http://1000memories.com
# 36             http://www.1000museums.com
# 37             http://www.1000museums.com
# 39             http://www.1000museums.com
# 40             http://www.1000museums.com
# 42             http://www.1000museums.com
# 44                 http://zenchef.com/en/
# 45                 http://zenchef.com/en/
# 47                 http://zenchef.com/en/
# 48         http://www.1001pharmacies.com/
# 50                    http://www.1006.tv/
# 51                    http://www.1006.tv/
# 52                   http://www.100du.com
# 53                   http://www.100du.com
# 54                    http://www.100e.com
# 55                    http://www.100e.com
# 57             http://www.redoxengine.com
# 59                 http://www.100plus.com
# 60                http://www.1010data.com
# ...                                   ...
# 114856                                NaN
# 114858                                NaN
# 114865                                NaN
# 114866                                NaN
# 114868                                NaN
# 114869                                NaN
# 114876                                NaN
# 114886                                NaN
# 114887                                NaN
# 114891                                NaN
# 114892                                NaN
# 114899                                NaN
# 114900                                NaN
# 114901                                NaN
# 114902                                NaN
# 114910                                NaN
# 114911                                NaN
# 114912                                NaN
# 114917                                NaN
# 114918                                NaN
# 114919                                NaN
# 114924                                NaN
# 114925                                NaN
# 114926                                NaN
# 114929                                NaN
# 114936                                NaN
# 114939                                NaN
# 114942                                NaN
# 114946                                NaN
# 114947                                NaN
#
#                                             category_list     status  \
# 0                                                   Media  operating
# 1       Application Platforms|Real Time|Social Network...  operating
# 3                                             Curated Web  operating
# 4                                                Software  operating
# 7                                           Biotechnology  operating
# 9                                               Analytics  operating
# 10                                              Analytics  operating
# 11                                              Analytics  operating
# 21                       Apps|Cable|Distribution|Software   acquired
# 27                                              Education  operating
# 31                                                 Beauty  operating
# 32                                            Curated Web   acquired
# 36                                            Curated Web  operating
# 37                                            Curated Web  operating
# 39                                            Curated Web  operating
# 40                                            Curated Web  operating
# 42                                            Curated Web  operating
# 44                           Local Businesses|Restaurants  operating
# 45                           Local Businesses|Restaurants  operating
# 47                           Local Businesses|Restaurants  operating
# 48                                 Cosmetics|Marketplaces  operating
# 50                                            Games|Media  operating
# 51                                            Games|Media  operating
# 52                                            Hospitality  operating
# 53                                            Hospitality  operating
# 54                                              Education  operating
# 55                                              Education  operating
# 57      Health Care|Health Care Information Technology...  operating
# 59                                              Analytics   acquired
# 60                                               Software   acquired
# ...                                                   ...        ...
# 114856                                                NaN        NaN
# 114858                                                NaN        NaN
# 114865                                                NaN        NaN
# 114866                                                NaN        NaN
# 114868                                                NaN        NaN
# 114869                                                NaN        NaN
# 114876                                                NaN        NaN
# 114886                                                NaN        NaN
# 114887                                                NaN        NaN
# 114891                                                NaN        NaN
# 114892                                                NaN        NaN
# 114899                                                NaN        NaN
# 114900                                                NaN        NaN
# 114901                                                NaN        NaN
# 114902                                                NaN        NaN
# 114910                                                NaN        NaN
# 114911                                                NaN        NaN
# 114912                                                NaN        NaN
# 114917                                                NaN        NaN
# 114918                                                NaN        NaN
# 114919                                                NaN        NaN
# 114924                                                NaN        NaN
# 114925                                                NaN        NaN
# 114926                                                NaN        NaN
# 114929                                                NaN        NaN
# 114936                                                NaN        NaN
# 114939                                                NaN        NaN
# 114942                                                NaN        NaN
# 114946                                                NaN        NaN
# 114947                                                NaN        NaN
#
#        country_code state_code                 region           city  \
# 0               IND         16                 Mumbai         Mumbai
# 1               USA         DE             DE - Other  Delaware City
# 3               CHN         22                Beijing        Beijing
# 4               USA         IL  Springfield, Illinois      Champaign
# 7               CAN         BC              Vancouver      Vancouver
# 9               USA         CA            SF Bay Area  Mountain View
# 10              USA         CA            SF Bay Area  Mountain View
# 11              USA         CA            SF Bay Area  Mountain View
# 21              USA         CA            SF Bay Area      Cupertino
# 27              GBR         H9                 London         London
# 31              IND         25                Chennai        Chennai
# 32              USA         CA            SF Bay Area  San Francisco
# 36              USA         MA             MA - Other          Lenox
# 37              USA         MA             MA - Other          Lenox
# 39              USA         MA             MA - Other          Lenox
# 40              USA         MA             MA - Other          Lenox
# 42              USA         MA             MA - Other          Lenox
# 44              FRA         A8                  Paris          Paris
# 45              FRA         A8                  Paris          Paris
# 47              FRA         A8                  Paris          Paris
# 48              FRA         A9            Montpellier    Montpellier
# 50              CHN         22                Beijing        Beijing
# 51              CHN         22                Beijing        Beijing
# 52              CHN         23               Shanghai       Shanghai
# 53              CHN         23               Shanghai       Shanghai
# 54              CHN         22                Beijing        Beijing
# 55              CHN         22                Beijing        Beijing
# 57              USA         WI                Madison        Madison
# 59              USA         CA            SF Bay Area  San Francisco
# 60              USA         NY          New York City       New York
# ...             ...        ...                    ...            ...
# 114856          NaN        NaN                    NaN            NaN
# 114858          NaN        NaN                    NaN            NaN
# 114865          NaN        NaN                    NaN            NaN
# 114866          NaN        NaN                    NaN            NaN
# 114868          NaN        NaN                    NaN            NaN
# 114869          NaN        NaN                    NaN            NaN
# 114876          NaN        NaN                    NaN            NaN
# 114886          NaN        NaN                    NaN            NaN
# 114887          NaN        NaN                    NaN            NaN
# 114891          NaN        NaN                    NaN            NaN
# 114892          NaN        NaN                    NaN            NaN
# 114899          NaN        NaN                    NaN            NaN
# 114900          NaN        NaN                    NaN            NaN
# 114901          NaN        NaN                    NaN            NaN
# 114902          NaN        NaN                    NaN            NaN
# 114910          NaN        NaN                    NaN            NaN
# 114911          NaN        NaN                    NaN            NaN
# 114912          NaN        NaN                    NaN            NaN
# 114917          NaN        NaN                    NaN            NaN
# 114918          NaN        NaN                    NaN            NaN
# 114919          NaN        NaN                    NaN            NaN
# 114924          NaN        NaN                    NaN            NaN
# 114925          NaN        NaN                    NaN            NaN
# 114926          NaN        NaN                    NaN            NaN
# 114929          NaN        NaN                    NaN            NaN
# 114936          NaN        NaN                    NaN            NaN
# 114939          NaN        NaN                    NaN            NaN
# 114942          NaN        NaN                    NaN            NaN
# 114946          NaN        NaN                    NaN            NaN
# 114947          NaN        NaN                    NaN            NaN
#
#         founded_at                     company_permalink  \
# 0              NaN                   /organization/-fame
# 1       04-09-2014                /organization/-qounter
# 3       01-01-2007                 /organization/0-6-com
# 4       01-01-2010        /organization/004-technologies
# 7       01-01-1997   /organization/0ndine-biomedical-inc
# 9       01-01-2011                  /organization/0xdata
# 10      01-01-2011                  /organization/0xdata
# 11      01-01-2011                  /organization/0xdata
# 21      01-03-2012            /organization/1-mainstream
# 27      01-01-2013         /organization/10-minutes-with
# 31      01-01-2008               /organization/1000lookz
# 32      01-07-2010            /organization/1000memories
# 36      01-01-2008         /organization/1000museums-com
# 37      01-01-2008         /organization/1000museums-com
# 39      01-01-2008         /organization/1000museums-com
# 40      01-01-2008         /organization/1000museums-com
# 42      01-01-2008         /organization/1000museums-com
# 44      20-11-2010              /organization/1001-menus
# 45      20-11-2010              /organization/1001-menus
# 47      20-11-2010              /organization/1001-menus
# 48      01-01-2012      /organization/1001pharmacies-com
# 50      01-01-2009                 /organization/1006-tv
# 51      01-01-2009                 /organization/1006-tv
# 52             NaN                /organization/100du-tv
# 53             NaN                /organization/100du-tv
# 54             NaN                /organization/100e-com
# 55             NaN                /organization/100e-com
# 57      04-07-2014               /organization/100health
# 59      16-09-2011                 /organization/100plus
# 60      01-01-2000                /organization/1010data
# ...            ...                                   ...
# 114856         NaN                /organization/zapitano
# 114858         NaN                  /organization/zapnip
# 114865         NaN                 /organization/zayante
# 114866         NaN                 /organization/zayante
# 114868         NaN           /organization/zdrowegeny-pl
# 114869         NaN            /organization/zebra-mobile
# 114876         NaN            /organization/zeis-excelsa
# 114886         NaN                 /organization/zentila
# 114887         NaN        /organization/zenvault-medical
# 114891         NaN                    /organization/zepp
# 114892         NaN                    /organization/zepp
# 114899         NaN                 /organization/zhongan
# 114900         NaN          /organization/zhongyou-group
# 114901         NaN                  /organization/ziebel
# 114902         NaN                    /organization/ziel
# 114910         NaN                    /organization/zimi
# 114911         NaN                  /organization/zimory
# 114912         NaN                  /organization/zimory
# 114917         NaN  /organization/zip-trade-technologies
# 114918         NaN                 /organization/zipidee
# 114919         NaN                /organization/zipmatch
# 114924         NaN                /organization/zkey-com
# 114925         NaN                  /organization/zlango
# 114926         NaN             /organization/zlote-mysli
# 114929         NaN                  /organization/zolk-c
# 114936         NaN                /organization/zootcard
# 114939         NaN        /organization/zte9-corporation
# 114942         NaN               /organization/zuoyebang
# 114946         NaN                   /organization/zyfin
# 114947         NaN                  /organization/ãeron
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 3       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 4       /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 7       /funding-round/954b9499724b946ad8c396a57a5f3b72            venture
# 9       /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 10      /funding-round/ae2a174c06517c2394aed45006322a7e            venture
# 11      /funding-round/e1cfcbe1bdf4c70277c5f29a3482f24e            venture
# 21      /funding-round/b952cbaf401f310927430c97b68162ea            venture
# 27      /funding-round/0faccbbcc5818dc5326469f13f5a8ac8            venture
# 31      /funding-round/e07f6e580046d00c7aeb33fafb9d90a3            venture
# 32      /funding-round/502bd0e50c27616995e4bdad24605ef8            venture
# 36      /funding-round/13be128d655076a025221d7fddc90d68            venture
# 37      /funding-round/6aeb32ab3fc05db2b606d7a2466e8c09            venture
# 39      /funding-round/89317984885b44f02e4befb9dc2e588c            venture
# 40      /funding-round/adf2f3272af9f552b87e01f10f0b9234            venture
# 42      /funding-round/fd1b3064232ba9b3cfb5653a619e82e8            venture
# 44      /funding-round/645b4cd895450b8e0268027cd7813047            venture
# 45      /funding-round/8025123b90c1ab687f9857ffe18bfd3b            venture
# 47      /funding-round/b6c28ea4ebe32db7083052cf87e7c368            venture
# 48      /funding-round/a21fc4d20200f43e3a25fd9cfc7c1482            venture
# 50      /funding-round/b6aeb7401ec6993f92a16cbca153b600            venture
# 51      /funding-round/c4dd206906e8f6834dde0eb9681002ac            venture
# 52      /funding-round/46a9d3228f69c036e8076f1362ac58cd            venture
# 53      /funding-round/8797d60368bb0227f0d0ab4c72aef886            venture
# 54      /funding-round/22a86670d1055d7bafce665b27e91871            venture
# 55      /funding-round/a136f7eb873dfb13cec839fef7d7f51e            venture
# 57      /funding-round/502f558bee350299fd1ae503e5b9a124            venture
# 59      /funding-round/b5facb0d9dea2f0352b5834892c88c53            venture
# 60      /funding-round/482fbf992b48f5c47d0080ab7ec0cb54            venture
# ...                                                 ...                ...
# 114856  /funding-round/b8cc64ca17fe3e08c7941f7a5d1329ae            venture
# 114858  /funding-round/943e9ff2b18bf47c66955f8a2db4a7e0            venture
# 114865  /funding-round/4fa0682bece28147b1fa7744afe952d1            venture
# 114866  /funding-round/a3df0815bd35430016a3199956c2f1f2            venture
# 114868  /funding-round/7ee6f14de370fe5117abc3c8d07f2d85            venture
# 114869  /funding-round/eddaab68bc76fcfe42ea1a1dddf26560            venture
# 114876  /funding-round/d3064ba5320af2e92fefcd1c541172a7            venture
# 114886  /funding-round/c4f4dc5f1dcafa35df7a9995164ddbe1            venture
# 114887  /funding-round/0d81e99aad9919e36e111c80ad4b9954            venture
# 114891  /funding-round/71546b6ae6804ab541f5661e6e23fd48            venture
# 114892  /funding-round/d33b506dcaf39b1b1d19ea898f40b2f6            venture
# 114899  /funding-round/803ea69810bad7f139e802c9cdfd8259            venture
# 114900  /funding-round/b06dd2b62b10a7203cac0df5ebd9c359            venture
# 114901  /funding-round/62457b9c6bc25a34429846e4b0ecf141            venture
# 114902  /funding-round/41c019e9fe1b77e2d031ec0f95f01e68            venture
# 114910  /funding-round/125587c8143c3ce039b19ccf6718b0b5            venture
# 114911  /funding-round/3fbdc8bc87129a16d9bad15d6fe90d2a            venture
# 114912  /funding-round/4692f2285983a12f823f05aaeb46d986            venture
# 114917  /funding-round/74b8565f7f28bf31ffcb62626d658654            venture
# 114918  /funding-round/31f2c14a34282e7f01d905fa369392df            venture
# 114919  /funding-round/817822b996f15c7f50b42636ecfed252            venture
# 114924  /funding-round/aca95e6dda1b354ebee80bca5f261607            venture
# 114925  /funding-round/203baf1c533923de0bc50699a12f447e            venture
# 114926  /funding-round/0787484a3d22104c752fe8a96d57abe4            venture
# 114929  /funding-round/327f2828712fa42899d272320ec31be6            venture
# 114936  /funding-round/c662b7cb18f7be11f811cc9c5b504bb6            venture
# 114939  /funding-round/e9e5a96d230dababfd3f9d2c63c702a5            venture
# 114942  /funding-round/720cfd18d9f4804df5cf722ca8116ec8            venture
# 114946  /funding-round/98cef3afd5e88487a9829ff182fb1a25            venture
# 114947  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
#
#        funding_round_code   funded_at  raised_amount_usd
# 0                       B  05-01-2015      10,000,000.00
# 1                       A  14-10-2014      10,426,869.33
# 3                       A  19-03-2008       2,000,000.00
# 4                     NaN  24-07-2014      10,426,869.33
# 7                     NaN  21-12-2009         719,491.00
# 9                       B  09-11-2015      20,000,000.00
# 10                    NaN  03-01-2013       1,700,000.00
# 11                      A  19-07-2014       8,900,000.00
# 21                    NaN  17-03-2015       5,000,000.00
# 27                      A  09-10-2014       4,000,000.00
# 31                    NaN  22-07-2013      10,426,869.33
# 32                      A  16-02-2011       2,520,000.00
# 36                    NaN  14-10-2009         265,940.00
# 37                    NaN  15-01-2014       2,906,832.00
# 39                    NaN  01-08-2014       1,500,000.00
# 40                    NaN  01-02-2014      10,426,869.33
# 42                    NaN  05-04-2011         642,000.00
# 44                      B  04-11-2015       6,602,694.00
# 45                      A  13-11-2013       1,736,910.00
# 47                      A  25-10-2013       1,800,000.00
# 48                      A  09-07-2015       8,900,000.00
# 50                      B  31-07-2014      10,000,000.00
# 51                      A  01-01-2013      10,426,869.33
# 52                      C  13-08-2010      10,426,869.33
# 53                      A  07-01-2008       3,000,000.00
# 54                    NaN  01-01-2006       3,000,000.00
# 55                    NaN  01-09-2006       1,500,000.00
# 57                      A  20-10-2015       3,530,000.00
# 59                    NaN  02-11-2011         500,000.00
# 60                    NaN  08-03-2010      35,000,000.00
# ...                   ...         ...                ...
# 114856                NaN  21-06-2013         684,471.00
# 114858                  A  26-04-2011          40,000.00
# 114865                  B  01-05-1999       1,500,000.00
# 114866                  A  01-10-1998       3,000,000.00
# 114868                NaN  17-08-2015      10,426,869.33
# 114869                  A  01-05-2008      10,426,869.33
# 114876                NaN  28-12-2011      26,148,000.00
# 114886                  A  22-05-2013       2,100,000.00
# 114887                NaN  10-06-2015         678,100.00
# 114891                  B  01-01-2014      15,000,000.00
# 114892                  A  01-01-2013       5,000,000.00
# 114899                  A  12-06-2015     931,300,000.00
# 114900                NaN  01-01-2004       4,500,000.00
# 114901                NaN  20-01-2014      10,000,000.00
# 114902                NaN  16-07-2015      10,426,869.33
# 114910                  B  18-03-2015      15,000,000.00
# 114911                NaN  08-07-2013      20,000,000.00
# 114912                NaN  04-10-2010       5,482,000.00
# 114917                  D  08-11-2007      20,000,000.00
# 114918                  A  14-10-2007      10,426,869.33
# 114919                  A  24-03-2015       2,500,000.00
# 114924                  B  22-11-1999      10,000,000.00
# 114925                  A  12-02-2007      12,000,000.00
# 114926                  A  01-01-2009      10,426,869.33
# 114929                NaN  13-01-2012         636,731.00
# 114936                NaN  26-06-2014         750,000.00
# 114939                  A  01-02-2014       2,059,308.00
# 114942                  A  03-09-2015      10,426,869.33
# 114946                  A  01-11-2011      10,426,869.33
# 114947                  A  01-08-2014      10,426,869.33
#
# [55494 rows x 16 columns]
#   country_code  raised_amount_usd
# 0          USA 445,794,042,019.92
# 1          CHN  45,288,671,434.95
# 2          GBR  22,831,491,010.96
# 3          IND  16,143,572,766.20
# 4          CAN  10,521,750,557.11
# 5          DEU   8,724,286,030.27
# 6          ISR   8,096,177,683.13
# 7          FRA   7,968,563,846.75
# 8          JPN   3,822,458,861.72
# 0                                                     Media
# 1         Application Platforms|Real Time|Social Network...
# 3                                               Curated Web
# 4                                                  Software
# 7                                             Biotechnology
# 9                                                 Analytics
# 10                                                Analytics
# 11                                                Analytics
# 21                         Apps|Cable|Distribution|Software
# 27                                                Education
# 31                                                   Beauty
# 32                                              Curated Web
# 36                                              Curated Web
# 37                                              Curated Web
# 39                                              Curated Web
# 40                                              Curated Web
# 42                                              Curated Web
# 44                             Local Businesses|Restaurants
# 45                             Local Businesses|Restaurants
# 47                             Local Businesses|Restaurants
# 48                                   Cosmetics|Marketplaces
# 50                                              Games|Media
# 51                                              Games|Media
# 52                                              Hospitality
# 53                                              Hospitality
# 54                                                Education
# 55                                                Education
# 57        Health Care|Health Care Information Technology...
# 59                                                Analytics
# 60                                                 Software
#                                 ...
# 114856                                                  NaN
# 114858                                                  NaN
# 114865                                                  NaN
# 114866                                                  NaN
# 114868                                                  NaN
# 114869                                                  NaN
# 114876                                                  NaN
# 114886                                                  NaN
# 114887                                                  NaN
# 114891                                                  NaN
# 114892                                                  NaN
# 114899                                                  NaN
# 114900                                                  NaN
# 114901                                                  NaN
# 114902                                                  NaN
# 114910                                                  NaN
# 114911                                                  NaN
# 114912                                                  NaN
# 114917                                                  NaN
# 114918                                                  NaN
# 114919                                                  NaN
# 114924                                                  NaN
# 114925                                                  NaN
# 114926                                                  NaN
# 114929                                                  NaN
# 114936                                                  NaN
# 114939                                                  NaN
# 114942                                                  NaN
# 114946                                                  NaN
# 114947                                                  NaN
# Name: category_list, Length: 55494, dtype: object
#                                                       count                sum
# country_code main_sector
# USA          Automotive & Sports                        566  12,268,203,725.40
#              Cleantech / Semiconductors                8113 121,517,135,484.31
#              Entertainment                             1888  17,944,177,890.15
#              Health                                    3403  33,120,695,672.83
#              Manufacturing                             2643  26,826,424,643.56
#              News, Search and Messaging                4562  47,340,732,188.31
#              Others                                    8693  86,776,669,245.53
#              Social, Finance, Analytics, Advertising   5553  66,202,459,933.80
# 35421
# 411996498783.8832
#                                                       count              sum
# country_code main_sector
# GBR          Automotive & Sports                         54   585,147,405.35
#              Cleantech / Semiconductors                 456 5,268,547,261.69
#              Entertainment                              157 1,391,526,114.03
#              Health                                     126 1,130,069,760.68
#              Manufacturing                              132 1,123,551,907.35
#              News, Search and Messaging                 265 3,206,268,613.03
#              Others                                     571 5,067,742,680.41
#              Social, Finance, Analytics, Advertising    359 3,278,617,920.71
# 2120
# 21051471663.238457
#                                                       count              sum
# country_code main_sector
# IND          Automotive & Sports                         32 1,566,776,869.33
#              Cleantech / Semiconductors                  63   880,286,457.01
#              Entertainment                               88 1,111,254,645.35
#              Health                                      56   710,346,170.68
#              Manufacturing                               64   824,101,824.01
#              News, Search and Messaging                 154 1,989,824,812.03
#              Others                                     329 6,818,997,168.06
#              Social, Finance, Analytics, Advertising    104 1,148,289,342.03
# 890
# 15049877288.502823
#                                            permalink  \
# 13843                   /organization/social-finance
# 30424                      /organization/coreexpress
# 19090                         /organization/zenefits
# 46602                         /organization/snapchat
# 20047                     /organization/livingsocial
# 19911                              /organization/jet
# 46603                         /organization/snapchat
# 39273                           /organization/opnext
# 19384                   /organization/carsdirect-com
# 45079         /organization/tenable-network-security
# 5305                      /organization/surveymonkey
# 45733                         /organization/facebook
# 30091                         /organization/hotchalk
# 18487                     /organization/pure-storage
# 13734                        /organization/maplebear
# 19860                        /organization/instacart
# 46606                         /organization/snapchat
# 36252                  /organization/gigabit-squared
# 45732                         /organization/facebook
# 13847                   /organization/social-finance
# 44296               /organization/social-finance-inc
# 30119                        /organization/lynda-com
# 5280            /organization/stream-global-services
# 18252                           /organization/mozido
# 20051                     /organization/livingsocial
# 20178                             /organization/myer
# 39230               /organization/aat-communications
# 20050                     /organization/livingsocial
# 15217       /organization/great-atlantic-pacific-tea
# 20915                          /organization/wayfair
# ...                                              ...
# 3727                            /organization/lecere
# 20030                 /organization/lien-enforcement
# 19335                    /organization/bourbon-boots
# 48123                          /organization/truefit
# 18956                        /organization/vectormax
# 3736                            /organization/lecere
# 3998             /organization/mobiform-software-inc
# 2637             /organization/cyber-kiosk-solutions
# 15274                           /organization/myfab5
# 18228                         /organization/mobiveil
# 1827                /organization/apogee-informatics
# 30022                         /organization/camperoo
# 20404                        /organization/pisociety
# 2510     /organization/computer-software-innovations
# 39644             /organization/davidson-instruments
# 18226                         /organization/mobiveil
# 3322                     /organization/ilink-systems
# 3152   /organization/globalgroup-investment-holdings
# 34464                          /organization/mobilio
# 14079                     /organization/secret-space
# 13771                        /organization/peers-app
# 4808                        /organization/rewardsnap
# 4372                            /organization/ozmott
# 4607                       /organization/proficiency
# 2914                          /organization/enviance
# 3315                            /organization/igor-2
# 18675                          /organization/skykick
# 4615                          /organization/promisec
# 17346                          /organization/appdome
# 5811              /organization/wellspring-worldwide
#
#                                   name  \
# 13843                             SoFi
# 30424                      CoreExpress
# 19090                         Zenefits
# 46602                         Snapchat
# 20047                     LivingSocial
# 19911                              Jet
# 46603                         Snapchat
# 39273                           Opnext
# 19384                   CarsDirect.com
# 45079         Tenable Network Security
# 5305                      SurveyMonkey
# 45733                         Facebook
# 30091                         Hotchalk
# 18487                     Pure Storage
# 13734                        Maplebear
# 19860                        Instacart
# 46606                         Snapchat
# 36252                  Gigabit Squared
# 45732                         Facebook
# 13847                             SoFi
# 44296                   Social Finance
# 30119                        lynda.com
# 5280            Stream Global Services
# 18252                           Mozido
# 20051                     LivingSocial
# 20178                             Myer
# 39230               AAT Communications
# 20050                     LivingSocial
# 15217     Great Atlantic & Pacific Tea
# 20915                          Wayfair
# ...                                ...
# 3727                            Lecere
# 20030                 Lien Enforcement
# 19335                  Bourbon & Boots
# 48123                          Truefit
# 18956                        VectorMAX
# 3736                            Lecere
# 3998            Mobiform Software Inc.
# 2637             Cyber Kiosk Solutions
# 15274                           myfab5
# 18228                         Mobiveil
# 1827                Apogee Informatics
# 30022                         Camperoo
# 20404                        piSociety
# 2510     Computer Software Innovations
# 39644             Davidson Instruments
# 18226                         Mobiveil
# 3322                     Ilink Systems
# 3152   GLOBALGROUP INVESTMENT HOLDINGS
# 34464                          Mobilio
# 14079                     Secret Space
# 13771                        Peers App
# 4808                        RewardSnap
# 4372                            Ozmott
# 4607                       Proficiency
# 2914                          Enviance
# 3315                              Igor
# 18675                          SkyKick
# 4615                          Promisec
# 17346                          AppDome
# 5811              Wellspring Worldwide
#
#                                        homepage_url  \
# 13843                           http://www.sofi.com
# 30424                    http://www.coreexpress.net
# 19090                       http://www.zenefits.com
# 46602                       http://www.snapchat.com
# 20047                   http://www.livingsocial.com
# 19911                           http://www.jet.com/
# 46603                       http://www.snapchat.com
# 39273                                           NaN
# 19384                     http://www.carsdirect.com
# 45079                        http://www.tenable.com
# 5305                    http://www.surveymonkey.com
# 45733                       http://www.facebook.com
# 30091                       http://www.hotchalk.com
# 18487                    http://www.purestorage.com
# 13734                      http://www.maplebear.in/
# 19860                      http://www.instacart.com
# 46606                       http://www.snapchat.com
# 36252                              http://gbps2.com
# 45732                       http://www.facebook.com
# 13847                           http://www.sofi.com
# 44296               http://www.socialfinanceus.org/
# 30119                          http://www.lynda.com
# 5280                              http://stream.com
# 18252                         http://www.mozido.com
# 20051                   http://www.livingsocial.com
# 20178                            http://myer.com.au
# 39230                       http://www.aatcomm.com/
# 20050                   http://www.livingsocial.com
# 15217                              http://aptea.com
# 20915                        http://www.wayfair.com
# ...                                             ...
# 3727                          http://www.lecere.com
# 20030             http://www.lienenforcementinc.com
# 19335                    http://bourbonandboots.com
# 48123              http://www.truefitinnovation.com
# 18956                          http://vectormax.com
# 3736                          http://www.lecere.com
# 3998                    http://www.StatusVision.com
# 2637                    http://www.cyber-thingy.com
# 15274                             http://myfab5.com
# 18228                           http://mobiveil.com
# 1827               http://www.apogeeinformatics.com
# 30022                       http://www.camperoo.com
# 20404                      http://www.pisociety.com
# 2510                        http://www.csi-plus.com
# 39644          http://www.davidson-instruments.com/
# 18226                           http://mobiveil.com
# 3322                       http://ilink-systems.com
# 3152   http://www.globalgroupinvestmentholdings.com
# 34464                                           NaN
# 14079                   http://www.secret-space.com
# 13771                                           NaN
# 4808                          http://rewardsnap.com
# 4372                              http://ozmott.com
# 4607                     http://www.proficiency.com
# 2914             http://www.enviance.com/index.aspx
# 3315                      http://www.igor-tech.com/
# 18675                        http://www.skykick.com
# 4615                        http://www.promisec.com
# 17346                       https://www.appdome.com
# 5811                      http://www.wellspring.com
#
#                                          category_list_x     status  \
# 13843  Education|Finance|Financial Services|Peer-to-Peer  operating
# 30424                                           Services   acquired
# 19090  Enterprise Software|Health and Insurance|Human...  operating
# 46602          File Sharing|Messaging|Mobile|Photography  operating
# 20047  E-Commerce|Group Buying|Networking|Social Comm...  operating
# 19911                  E-Commerce|Online Shopping|Retail  operating
# 46603          File Sharing|Messaging|Mobile|Photography  operating
# 39273                                 Telecommunications        ipo
# 19384                                         E-Commerce  operating
# 45079                           Mobile Security|Security  operating
# 5305                                    Software|Surveys  operating
# 45733  All Students|Colleges|Communities|Identity|Soc...        ipo
# 30091                                   EdTech|Education  operating
# 18487                        Enterprise Software|Storage        ipo
# 13734                                          Education  operating
# 19860              E-Commerce|Groceries|Local Businesses  operating
# 46606          File Sharing|Messaging|Mobile|Photography  operating
# 36252                                        Web Hosting  operating
# 45732  All Students|Colleges|Communities|Identity|Soc...        ipo
# 13847  Education|Finance|Financial Services|Peer-to-Peer  operating
# 44296                                         Nonprofits  operating
# 30119                                   EdTech|Education   acquired
# 5280                                            Software   acquired
# 18252  Enterprise Software|Mobile Commerce|Mobile Pay...  operating
# 20051  E-Commerce|Group Buying|Networking|Social Comm...  operating
# 20178                                         E-Commerce  operating
# 39230                                 Telecommunications  operating
# 20050  E-Commerce|Group Buying|Networking|Social Comm...  operating
# 15217                                        Hospitality  operating
# 20915                        E-Commerce|Furniture|Retail        ipo
# ...                                                  ...        ...
# ...
# 1147                   /organization/redbus-in
# 45516                /organization/saraf-foods
# 482              /organization/dealsandyou-com
# 22073        /organization/nazara-technologies
# 13424         /organization/tinyowl-technology
# 37939                /organization/delyver-com
# 22606         /organization/united-mobile-apps
# 724                   /organization/indiahomes
# 22071        /organization/nazara-technologies
# 13320  /organization/red-panda-innovation-labs
# 32952                     /organization/exotel
# 13318                  /organization/railyatri
# 13365                /organization/smartpocket
# 48240               /organization/room-n-house
# 41980                  /organization/youtellme
# 13489                       /organization/zify
#
#                                funding_round_permalink funding_round_type  \
# 1123   /funding-round/c3d8b1a4db1354d4c3dbc60a8171565f            venture
# 1124   /funding-round/ce9bc87569765200a4ba52d06071e466            venture
# 26172  /funding-round/6584c8fed1cede9215e8d712a6534530            venture
# 32969  /funding-round/73d21a2875dbc2e1f9fef92aeac3b72a            venture
# 1120   /funding-round/75d6aa7365247e6c23fe83220a40c9c4            venture
# 45368  /funding-round/7772965d03013f4da87bec7c28d0f7e7            venture
# 30963  /funding-round/72a1ee7f6b21ed3e7da7896680f817ef            venture
# 723    /funding-round/29c155d8267eec68ff47dd6a03c1b8bf            venture
# 21928  /funding-round/84fb8f601565bf0ff4aca5e054d46b17            venture
# 21929  /funding-round/f6496bbca4159b1f4db5434ab477849a            venture
# 29459  /funding-round/ced099f7517bf9845b85c4e44584fd6a            venture
# 39131  /funding-round/fd37a917f686c3080718b9cde8b1be14            venture
# 13279  /funding-round/fe0f32357b940f0ba74e39dcddada95c            venture
# 26173  /funding-round/9b2621c9f05a2018423eb32c9a843166            venture
# 1119   /funding-round/0af7f5ddac4e13869d065764ab56b5f8            venture
# 22122  /funding-round/0590aae6fb25bd39a6d2df6a7489c484            venture
# 13448  /funding-round/e87ffbfd19d184cbc04e133522571c50            venture
# 882    /funding-round/2475a82c691000cb1909a8ca665addab            venture
# 725    /funding-round/67c2e7ebf2fc4d11e38c3ce2e16d963e            venture
# 21548  /funding-round/66e181aeac673e359046cd11952908b3            venture
# 336    /funding-round/8b6a337fc018e33d6eec303c8acc8075            venture
# 45445  /funding-round/de76c6281c35d53c17bc537482187248            venture
# 22781  /funding-round/aa92ee11012093420448630238e66a96            venture
# 26278  /funding-round/144757a882b97681eb9c366545f8f9d4            venture
# 44243  /funding-round/4818ab30d647cf78b67154f2b299dce3            venture
# 29458  /funding-round/0982c9ebee30d9803a735cde546416bf            venture
# 481    /funding-round/1d10b4023785820d9c51de60274d0e22            venture
# 13423  /funding-round/87c8a4d69f56bef8652c2bc307cfc795            venture
# 30811  /funding-round/d77962c145e9677747284d7b9ff3a7ff            venture
# 315    /funding-round/cac1371e6c9a38eb8e8409b2ebca9ec8            venture
# ...                                                ...                ...
# 37859  /funding-round/4d49b2a7dce9550a6c8444ce9c7aaca6            venture
# 26197  /funding-round/a360a29c5822a7f9c32a246c69dd40ea            venture
# 43310  /funding-round/d1be627d99fe207142041b1bc4966f40            venture
# 22013  /funding-round/1323c77cac7a98553a0e2a2fe3f70b05            venture
# 32965  /funding-round/6d5d3f62c5601a2e443d57bd126c0665            venture
# 47032  /funding-round/d8f9f8871d8025382537fa1710b0284e            venture
# 13439  /funding-round/4358e7a6bc5dafe7fd0a7e00c935fe72            venture
# 32908  /funding-round/1aa6eb158990aed36c1160c23a96c298            venture
# 1403   /funding-round/c7485dcdf375c9b55707026955db149b            venture
# 625    /funding-round/bb97ac06bff73419d44ce1053e2a2c4e            venture
# 340    /funding-round/211949bc570cdf1753b2efc043f37e93            venture
# 564    /funding-round/ef34624c62562fe42cb7c3a247ce1b01            venture
# 22005  /funding-round/c806e2ba2e1fc434838ce8767e45538d            venture
# 22778  /funding-round/4216727a2d759b333272a6a4a46b0038            venture
# 1147   /funding-round/c8487e0406c08b44bc167c2bf05df48d            venture
# 45516  /funding-round/f33fabc3d02090a2445e2e8ae8af10eb            venture
# 482    /funding-round/a891dd9b826883c20cd98e17b72cf6e0            venture
# 22073  /funding-round/cd855920d9f241050f82e3f7ad2d2195            venture
# 13424  /funding-round/b4be6c705ec7d1b5bbf7e9db6b60f844            venture
# 37939  /funding-round/e9d7f5b885ed73f17a2764f74b9cb2f8            venture
# 22606  /funding-round/063291062f752cb9b736492a9e4150b4            venture
# 724    /funding-round/327accdb3f0ad4dde209d797210100f1            venture
# 22071  /funding-round/19b7b4c5d4cade939497d9d6550c5a53            venture
# 13320  /funding-round/ae6d42e493ce9888722b74745a51401c            venture
# 32952  /funding-round/6cf63f809bfa3e570bee3c133ca883ec            venture
# 13318  /funding-round/29aeff452a735cfd607dc58ddb93291a            venture
# 13365  /funding-round/5ab055586ae170a89234c0a3560d3f14            venture
# 48240  /funding-round/4df20047596148cfd5553a7ef5b55903            venture
# 41980  /funding-round/7498616cbec07dbe55df9c53a8fafc66            venture
# 13489  /funding-round/83d0ec8f3da7a2e8fde8cdb9d5c4c27e            venture
#
#       funding_round_code   funded_at  raised_amount_usd  \
# 1123                   H  07-04-2015     150,000,000.00
# 1124                   F  11-03-2014      90,000,000.00
# 26172                  C  05-02-2015      80,000,000.00
# 32969                  C  26-08-2014      65,000,000.00
# 1120                   G  17-09-2014      60,000,000.00
# 45368                  E  27-06-2012      57,000,000.00
# 30963                NaN  07-05-2015      52,000,000.00
# 723                  NaN  02-12-2014      50,000,000.00
# 21928                NaN  12-01-2010      45,000,000.00
# 21929                NaN  20-09-2010      43,000,000.00
# 29459                  C  06-02-2015      40,000,000.00
# 39131                  A  03-06-2013      36,400,000.00
# 13279                  B  29-09-2015      36,000,000.00
# 26173                  B  01-09-2014      33,000,000.00
# 1119                   E  22-05-2012      32,000,000.00
# 22122                NaN  23-10-2008      25,000,000.00
# 13448                  B  19-11-2015      25,000,000.00
# 882                    B  08-04-2015      25,000,000.00
# 725                  NaN  16-04-2014      24,800,000.00
# 21548                  C  07-08-2015      23,500,000.00
# 336                  NaN  29-11-2013      22,400,000.00
# 45445                NaN  09-02-2012      21,000,000.00
# 22781                  B  04-06-2015      20,000,000.00
# 26278                  B  09-07-2015      20,000,000.00
# 44243                NaN  10-03-2015      20,000,000.00
# 29458                  B  22-09-2014      18,000,000.00
# 481                    B  01-11-2011      17,000,000.00
# 13423                  B  26-02-2015      16,000,000.00
# 30811                  B  28-07-2014      16,000,000.00
# 315                    C  09-07-2015      15,800,000.00
# ...                  ...         ...                ...
# 37859                  A  03-06-2015       3,000,000.00
# 26197                  A  19-11-2015       3,000,000.00
# 43310                  A  25-10-2013       2,900,000.00
# 22013                NaN  09-09-2015       2,585,114.00
# 32965                  A  18-11-2015       2,500,000.00
# 47032                  A  14-10-2015       2,500,000.00
# 13439                  A  09-03-2015       2,500,000.00
# 32908                NaN  30-01-2008       2,500,000.00
# 1403                   A  19-08-2015       2,200,000.00
# 625                    A  01-02-2007       2,000,000.00
# 340                    A  01-11-2007       2,000,000.00
# 564                  NaN  11-02-2015       2,000,000.00
# 22005                  B  01-12-2013       2,000,000.00
# 22778                NaN  14-03-2007       1,700,000.00
# 1147                   B  01-06-2009       1,690,000.00
# 45516                NaN  28-01-2014       1,600,000.00
# 482                    A  01-08-2010       1,500,000.00
# 22073                  A  19-10-2005       1,500,000.00
# 13424                  A  22-08-2014       1,000,000.00
# 37939                NaN  28-11-2014       1,000,000.00
# 22606                  A  26-04-2012       1,000,000.00
# 724                    G  27-08-2015         976,000.00
# 22071                NaN  28-11-2013         801,500.00
# 13320                NaN  01-09-2011         500,000.00
# 32952                  A  27-03-2012         500,000.00
# 13318                NaN  20-11-2014         486,000.00
# 13365                NaN  02-02-2015         240,000.00
# 48240                NaN  16-07-2014         166,396.00
# 41980                NaN  09-12-2014         100,000.00
# 13489                NaN  18-12-2014          40,000.00
#
#                    primary_sector             category_list_y  \
# 1123                  curated web                 curated web
# 1124                  curated web                 curated web
# 26172                    internet                    internet
# 32969                   messaging                   messaging
# 1120                  curated web                 curated web
# 45368                local search                local search
# 30963             cloud computing             cloud computing
# 723                   curated web                 curated web
# 21928                      mobile                      mobile
# 21929                      mobile                      mobile
# 29459                        news                        news
# 39131                      search                      search
# 13279                        apps                        apps
# 26173                    internet                    internet
# 1119                  curated web                 curated web
# 22122                      mobile                      mobile
# 13448                        apps                        apps
# 882                   curated web                 curated web
# 725                   curated web                 curated web
# 21548                      mobile                      mobile
# 336                   curated web                 curated web
# 45445                  app stores                  app stores
# 22781                      mobile                      mobile
# 26278                    internet                    internet
# 44243  internet service providers  internet service providers
# 29458                        news                        news
# 481                   curated web                 curated web
# 13423                        apps                        apps
# 30811             cloud computing             cloud computing
# 315                   curated web                 curated web
# ...                           ...                         ...
# 37859      commercial real estate      commercial real estate
# 26197                    internet                    internet
# 43310               online travel               online travel
# 22013                      mobile                      mobile
# 32965                   messaging                   messaging
# 47032                        chat                        chat
# 13439                        apps                        apps
# 32908                   messaging                   messaging
# 1403                  curated web                 curated web
# 625                   curated web                 curated web
# 340                   curated web                 curated web
# 564                   curated web                 curated web
# 22005                      mobile                      mobile
# 22778                      mobile                      mobile
# 1147                  curated web                 curated web
# 45516                    delivery                    delivery
# 482                   curated web                 curated web
# 22073                      mobile                      mobile
# 13424                        apps                        apps
# 37939             online shopping             online shopping
# 22606                      mobile                      mobile
# 724                   curated web                 curated web
# 22071                      mobile                      mobile
# 13320                        apps                        apps
# 32952                   messaging                   messaging
# 13318                        apps                        apps
# 13365                        apps                        apps
# 48240                peer-to-peer                peer-to-peer
# 41980         comparison shopping         comparison shopping
# 13489                        apps                        apps
#
#                       main_sector  value
# 1123   News, Search and Messaging      1
# 1124   News, Search and Messaging      1
# 26172  News, Search and Messaging      1
# 32969  News, Search and Messaging      1
# 1120   News, Search and Messaging      1
# 45368  News, Search and Messaging      1
# 30963  News, Search and Messaging      1
# 723    News, Search and Messaging      1
# 21928  News, Search and Messaging      1
# 21929  News, Search and Messaging      1
# 29459  News, Search and Messaging      1
# 39131  News, Search and Messaging      1
# 13279  News, Search and Messaging      1
# 26173  News, Search and Messaging      1
# 1119   News, Search and Messaging      1
# 22122  News, Search and Messaging      1
# 13448  News, Search and Messaging      1
# 882    News, Search and Messaging      1
# 725    News, Search and Messaging      1
# 21548  News, Search and Messaging      1
# 336    News, Search and Messaging      1
# 45445  News, Search and Messaging      1
# 22781  News, Search and Messaging      1
# 26278  News, Search and Messaging      1
# 44243  News, Search and Messaging      1
# 29458  News, Search and Messaging      1
# 481    News, Search and Messaging      1
# 13423  News, Search and Messaging      1
# 30811  News, Search and Messaging      1
# 315    News, Search and Messaging      1
# ...                           ...    ...
# 37859  News, Search and Messaging      1
# 26197  News, Search and Messaging      1
# 43310  News, Search and Messaging      1
# 22013  News, Search and Messaging      1
# 32965  News, Search and Messaging      1
# 47032  News, Search and Messaging      1
# 13439  News, Search and Messaging      1
# 32908  News, Search and Messaging      1
# 1403   News, Search and Messaging      1
# 625    News, Search and Messaging      1
# 340    News, Search and Messaging      1
# 564    News, Search and Messaging      1
# 22005  News, Search and Messaging      1
# 22778  News, Search and Messaging      1
# 1147   News, Search and Messaging      1
# 45516  News, Search and Messaging      1
# 482    News, Search and Messaging      1
# 22073  News, Search and Messaging      1
# 13424  News, Search and Messaging      1
# 37939  News, Search and Messaging      1
# 22606  News, Search and Messaging      1
# 724    News, Search and Messaging      1
# 22071  News, Search and Messaging      1
# 13320  News, Search and Messaging      1
# 32952  News, Search and Messaging      1
# 13318  News, Search and Messaging      1
# 13365  News, Search and Messaging      1
# 48240  News, Search and Messaging      1
# 41980  News, Search and Messaging      1
# 13489  News, Search and Messaging      1
#
# [154 rows x 20 columns]
